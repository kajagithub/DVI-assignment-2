# %% [markdown]
# <a href="https://colab.research.google.com/github/kajagithub/DVI-assignment-2/blob/main/dvi_a2_ps3_wb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src = "https://www.bits-pilani.ac.in/Uploads/Campus/BITS_university_logo.gif">

# %% [markdown]
# <h1><center>Work Integrated Learning Programmes Division<br>
# M.Tech (Data Science and Engineering)<br> Data Visualization And Interpretation (DSECL ZG555))<br>
# Second Semester, 2021-22
# </center></h1>
#
# <h2><center>Assignment 2 – PS3 [Weightage 13%]</center></h2>

# %% [markdown]
# <ol>
#   <li>Do not change the name of the data file that is shared with the problem statement.</li>
#   <li>If intermediate data files are created, retain in the present working directory and attach them during submission.</li>
#   <li>Retain the data file in the same directory as that of this workbook.</li>
#   <li>Retain the Visualizations that is produced in the file. Don't clear them away.</li>
#      <li><div class="alert-warning">All the visuals should adhere to the visualization principles learnt in the Course and must be presentation ready.Most effective visuals would fetch maximum credits</div></li>
#     <li><div class="alert-warning">Submissions done via means other than CANVAS will strictly be NOT graded.</div></li>
# </ol>

# %% [markdown]
# <style>
# table {
#   font-family: arial, sans-serif;
#   border-collapse: collapse;
#   width: 100%;
# }
#
# td, th {
#   border: 1px solid #dddddd;
#   text-align: left;
#   padding: 8px;
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
#
# <h2>Group No 41</h2>
#
# <table>
#   <tr>
#     <th>Full Name</th>
#     <th>BITS ID</th>
#   </tr>
#   <tr>
#     <td>Kaja Sai Manoj</td>
#     <td>2022da04301</td>
#   </tr>
#   <tr>
#     <td>Venkateswara Rao Manikeswaram</td>
#     <td>2022da04319</td>
#   </tr>
#   <tr>
#     <td>Nagaraju Mandadi P</td>
#     <td>2022da04542</td>
#   </tr>
#     <tr>
#     <td>Sajjad Manal</td>
#     <td>2022da04153</td>
#   </tr>
# </table>

# %% [markdown]
# <h3>Objective</h3>
# <h4>What are the features that have the most impact on the car price?</h4>

# %% [markdown]
# ##  Download and Prep the Data: 1 Mark

# %% [markdown]
# <h4>Import the libraries needed</h4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h4> Load data and store in dataframe </h4>

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# auto = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dvi-a2-ps3-data.csv')

# %%
auto = pd.read_csv('https://raw.githubusercontent.com/kajagithub/DVI-assignment-2/main/dvi-a2-ps3-data.csv')

# %% [markdown]
# <h4>Find out  what type of variable you are dealing with. This will help you find the right visualization method for that variable.</p>

# %%
auto.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   aspiration         201 non-null    object
#  4   num-of-doors       201 non-null    object
#  5   body-style         201 non-null    object
#  6   drive-wheels       201 non-null    object
#  7   engine-location    201 non-null    object
#  8   wheel-base         201 non-null    float64
#  9   length             201 non-null    float64
#  10  width              201 non-null    float64
#  11  height             201 non-null    float64
#  12  curb-weight        201 non-null    int64
#  13  engine-type        201 non-null    object
#  14  num-of-cylinders   201 non-null    object
#  15  engine-size        201 non-null    int64
# ...

# %% [markdown]
# <h4> Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.<br>
# Write down your observations in a markdown cell below. <h4>

# %%
columns_of_interest = ['bore', 'stroke', 'compression-ratio', 'horsepower']

#Correlation heat map
correlation_matrix = auto[columns_of_interest].corr()
chp = sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt=".2f", linewidths=0.5, cbar=True).set(title='Correlation Heatmap')
plt.show()

# %%
#pairplot
pp = sns.pairplot(data = auto[columns_of_interest])
pp.fig.suptitle("Pairplots between Bore, Stroke, Compression Ratio, Horse Power", y = 1.03)
plt.show()

# %% [markdown]
# ### **Observations**
#
# From the scatter plots and correlation heatmap plotted for the attributes "bore," "stroke," "compression-ratio," and "horsepower," here are some observations:
#
# 1. **Bore vs. Horsepower**:
#    - The scatter plot shows a relatively weak positive correlation between "bore" and "horsepower." As "bore" increases, "horsepower" tends to increase, but the relationship is not very strong.
#
# 2. **Stroke vs. Horsepower**:
#    - The scatter plot suggests a relatively weak correlation between "stroke" and "horsepower." There doesn't appear to be a clear linear relationship between these two variables.
#
# 3. **Compression-Ratio vs. Horsepower**:
#    - The scatter plot indicates a very weak negative correlation between "compression-ratio" and "horsepower." As "compression-ratio" increases, "horsepower" tends to decrease slightly, but the relationship is almost negligible.
#
# 4. **Bore vs. Compression-Ratio**:
#    - The scatter plot shows no strong correlation between "bore" and "compression-ratio." The data points are scattered without a clear pattern.
#
# 5. **Bore vs. Stroke**:
#    - The scatter plot for "bore" and "stroke" also displays no strong correlation. The data points are dispersed without a distinct linear relationship.
#
# 6. **Stroke vs. Compression-Ratio**:
#    - The scatter plot between "stroke" and "compression-ratio" reveals a lack of significant correlation. The data points do not exhibit a clear linear pattern.
#
# **Overall Correlations**:
#    - The correlation heatmap confirms the observations from the scatter plots. Most of the correlation coefficients are close to zero, indicating weak correlations between these variables.
#    - "Bore" and "Horsepower" have the highest correlation among the selected variables, but it is still relatively weak.
#
#    =============================================================================

# %% [markdown]
# # Visualisation Questions - 2X5 = 10 Marks

# %% [markdown]
# ### Question 1
# <h4>What kind of a correlation exists between<br><br>
#     a."engine-size" and "price"<br><br>
#     b."highway-mpg" and "price"<br><br>
#     c."peak-rpm" and "price"<br><br>
#     Use appropriate visuals to demonstrate the same.Use subplots.
# <h4>Clearly mention in markdown cells below the visual <br><br>1.You obseravtaion about the relationship. Which among engine-size, highway-mpg and peak-rpm is a potential predictor variable of price.<br>
#     2.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     3.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Correlation matrix (CM) for observation purposes

col_of_interest = ['highway-mpg', 'engine-size', 'peak-rpm', 'price']

#Correlation heat map
correlation_matrix = auto[col_of_interest].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt=".2f", linewidths=0.5, cbar=True).set(title='Correlation Heatmap')
plt.show()

# %%
# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Set colors and titles for each subplot
colors = ['#33FF57','#FF5733', '#5733FF']
titles = ['Regression Plot for Engine Size vs. Price',
          'Regression Plot for Highway MPG vs. Price',
          'Regression Plot for Peak RPM vs. Price']

# Create regression plots for each variable pair
for i, (x_var, title) in enumerate(zip(['engine-size', 'highway-mpg', 'peak-rpm'], titles)):
    sns.regplot(data=auto, x=x_var, y='price', ax=axes[i], color=colors[i])
    axes[i].set_title(title, fontsize=14, fontweight='bold')
    axes[i].set_xlabel(x_var.replace('-', ' ').title(), fontsize=12)
    axes[i].set_ylabel('Price', fontsize=12)
    axes[i].tick_params(axis='both', labelsize=10)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**:
#
# 1. **Engine Size vs. Price**:
#    - Observation: There appears to be a positive linear relationship between "engine-size" and "price." As "engine-size" increases, "price" tends to increase.
#    - Potential Predictor: "Engine-size" is a potential predictor variable of "price."
#
# 2. **Highway MPG vs. Price**:
#    - Observation: There is a negative linear relationship between "highway-mpg" and "price." As "highway-mpg" increases (indicating better fuel efficiency), "price" tends to decrease.
#    - Potential Predictor: "Highway-mpg" is a potential predictor variable of "price."
#
# 3. **Peak RPM vs. Price**:
#    - Observation: There is no strong linear relationship between "peak-rpm" and "price." The data points are scattered without a clear linear pattern.
#    - Potential Predictor: "Peak-rpm" is not a strong predictor variable of "price."
#
# **Pre-attentive Attributes Used**:
#
# 1. **Color**: The data points in the scatter plots are represented by dots with different colors. Color is used to distinguish data points from each other.
#
# 2. **Position (X and Y)**: The position of each data point on the X and Y axes represents the values of the corresponding variables, making it easy to visually compare and assess the relationship between variables.
#
# **Gestalt Principles Used**:
#
# 1. **Proximity**: In each scatter plot, the proximity of data points to each other on the chart conveys their relationship. Data points that are closer to each other tend to be related in terms of their "price" and the respective variable being analyzed.
#
# 2. **Similarity**: The similarity in the appearance of data points (e.g., size, shape) in the scatter plots aids in grouping and identifying patterns or trends in the data.
#
# In summary, based on the visualizations and analysis:
#
# - "Engine-size" and "Highway-mpg" are potential predictor variables of "price."
# - "Peak-rpm" does not show a strong linear relationship with "price" and is not a strong predictor variable.
#
# =============================================================================

# %% [markdown]
# ### Question 2
# <h4> Use boxplots to visualise the relationship between<br><br>
#     a."body-style" and "price". <br><br>
#     b."engine-location" and "price" <br><br>
#     c."drive-wheels"and "price" <br><br>
#     Use appropriate visuals to demonstrate the same.Use subplots.
# <h4>Clearly mention in markdown cells below the visual <br><br>1.Your observataion about the relationship .Which among engine-location ,body-style and drive-wheels is a potential predictor variable of price<br>
#     2.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     3.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Set colors, labels, and titles for each subplot
a = ['#c5df4d','#dfed9c', '#cbe261', '#d2e674', '#d8e988']
b = ['#99cdd6', '#b0d8e0', '#bbdde4', '#d2e9ed', '#e8f4f6']
c = ['#7a8394', '#d3d6db', '#d3d6db', '#9097a6', '#a6acb8']
colors = [b, a, c]
labels = ['Body Style vs. Price', 'Engine Location vs. Price', 'Drive Wheels vs. Price']
titles = ['Boxplot for Body Style vs. Price',
          'Boxplot for Engine Location vs. Price',
          'Boxplot for Drive Wheels vs. Price']

# Create boxplots for each variable pair
for i, (x_var, label, title) in enumerate(zip(['body-style', 'engine-location', 'drive-wheels'], labels, titles)):
    sns.boxplot(data=auto, x=x_var, y='price', ax=axes[i], palette = colors[i])
    axes[i].set_title(title, fontsize=14, fontweight='bold')
    axes[i].set_xlabel(x_var.replace('-', ' ').title(), fontsize=12)
    axes[i].set_ylabel('Price', fontsize=12)
    axes[i].tick_params(axis='both', labelsize=10)
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=0)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**:
#
# 1. **Body Style vs. Price**:
#    - Boxplot Observation: The boxplot shows the distribution of "price" for different categories of "body-style." There are noticeable variations in the distribution of prices across different body styles. For example, "convertible" and "hardtop" tend to have higher median prices compared to "sedan" and "wagon."
#    - Potential Predictor: "Body-style" is a potential predictor variable of "price."
#
# 2. **Engine Location vs. Price**:
#    - Boxplot Observation: The boxplot displays the distribution of "price" for different categories of "engine-location." It shows a significant difference in price distribution between "front" and "rear" engine locations. "Rear" engine location tends to have higher-priced cars.
#    - Potential Predictor: "Engine-location" is a potential predictor variable of "price."
#
# 3. **Drive Wheels vs. Price**:
#    - Boxplot Observation: The boxplot illustrates the distribution of "price" for different categories of "drive-wheels." It reveals variations in price distribution among "fwd," "rwd," and "4wd" drive-wheel types. "rwd" cars tend to have a wider range of prices with some higher-priced outliers.
#    - Potential Predictor: "Drive-wheels" is a potential predictor variable of "price."
#
# **Pre-attentive Attributes Used**:
#
# 1. **Color**: Each subplot uses a different color palette to distinguish between the categorical variables.
# 2. **Position (X and Y)**: The position of data points on the X and Y axes represents the values of the respective variables.
# 3. **Size**: The size of the labels, titles, and tick labels is adjusted for readability.
# 4. **Font Style**: Bold and normal font styles are used to emphasize titles and labels.
# 5. **Rotation**: The x-axis labels are rotated for improved readability.
#
# **Gestalt Principles Used**:
#
# 1. **Proximity**: The placement of titles, labels, and legends near the relevant visual elements (e.g., boxplots) ensures that viewers associate the text with the corresponding data.
#
# 2. **Similarity**: The use of consistent colors, font styles, and label sizes across the subplots enhances the visual similarity within each visualization and makes them easily distinguishable from one another.
#
# 3. **Continuity**: The continuous representation of the data within each boxplot allows viewers to assess the distribution and variability of "price" within each category.
#
# 4. **Closure**: The subplots provide closure around each individual analysis, separating and organizing the visualizations.
#
# In summary, based on the enhanced boxplots and analysis:
#
# - "Body-style," "Engine-location," and "Drive-wheels" are potential predictor variables of "price" based on the observed variations in price distribution among categories within each variable.

# %% [markdown]
# ### Question 3
# <h4> Perform a Descriptive Statistical Analysis of the data set.<br>
#     Compute basic statistics for all continuous variables.
#     <h4>Answer in markdown cells below the visual <br><br>
#         1.Summarise your findings from the visual.<br>
#             2.The reason for selecting the chart type you did. <br>
#                 3.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
###computing basic statistics###
#Extracting continuous variables from data set
continuous_vars = auto.select_dtypes(include=['float64', 'int64'])
continuous_var_list = continuous_vars.columns.tolist()

import scipy.stats as stats

# Function to calculate 5-point summary
def five_point_summary(data):
    return [
        data.min(),
        np.percentile(data, 25),
        np.percentile(data, 50),
        np.percentile(data, 75),
        data.max()
    ]

# Function to calculate IQR
def iqr(data):
    return np.percentile(data, 75) - np.percentile(data, 25)

# Calculate skewness and kurtosis
skewness = continuous_vars.apply(stats.skew)
kurt = continuous_vars.apply(stats.kurtosis)

# Create a summary table
summary_table = pd.DataFrame({
    'Min': continuous_vars.min(),
    'Q1': continuous_vars.apply(lambda x: np.percentile(x, 25)),
    'Median (Q2)': continuous_vars.median(),
    'Q3': continuous_vars.apply(lambda x: np.percentile(x, 75)),
    'Max': continuous_vars.max(),
    'IQR': continuous_vars.apply(iqr),
    'Skewness': skewness,
    'Kurtosis': kurt
})

# Print the 5-point summary, skewness, and kurtosis
print("5-Point Summary, Skewness, and Kurtosis:")
print(summary_table)
# Out:
# 5-Point Summary, Skewness, and Kurtosis:
#                            Min           Q1   Median (Q2)            Q3  \
# symboling            -2.000000     0.000000      1.000000      2.000000
# normalized-losses    65.000000   101.000000    122.000000    137.000000
# wheel-base           86.600000    94.500000     97.000000    102.400000
# length                0.678039     0.801538      0.832292      0.881788
# width                 0.837500     0.890278      0.909722      0.925000
# height               47.800000    52.000000     54.100000     55.500000
# curb-weight        1488.000000  2169.000000   2414.000000   2926.000000
# engine-size          61.000000    98.000000    120.000000    141.000000
# bore                  2.540000     3.150000      3.310000      3.580000
# stroke                2.070000          NaN      3.290000           NaN
# compression-ratio     7.000000     8.600000      9.000000      9.400000
# ...

# %%
#List all continuous variable attributes

print("continuous variables: ", len(continuous_var_list))
print(continuous_var_list)
print("")

# Create a boxplot for each continuous variable
fig, axes = plt.subplots(4, 5, figsize=(16, 16))
fig.suptitle("Descriptive Statistical Analysis of Continuous Variables", fontsize=16, fontweight='bold')
fig.subplots_adjust(wspace=0.5, hspace=0.5)
for i, var in enumerate(continuous_vars):
    row, col = divmod(i, 5)
    sns.boxplot(data=auto, y=var, ax=axes[row, col])
    axes[row, col].set_title(f'{var}')
    axes[row, col].set_xlabel('')
    axes[row, col].set_ylabel('')

# Remove empty subplots
for i in range(len(continuous_vars), 4 * 5):
    row, col = divmod(i, 5)
    fig.delaxes(axes[row, col])

# Show the boxplots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# continuous variables:  19
# ['symboling', 'normalized-losses', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price', 'city-L/100km', 'diesel', 'gas']

# %% [markdown]
# **Findings**:
#
# 1. **Summarized Findings**:
#    - The box plots provide a summary of the distribution of each continuous variable in the dataset.
#    - Variables like "Price," "curb-weight," and "Peak-rpm" have a wide range of values and show variations in the central tendency and spread.
#    - Variables like "compression-ratio", "Length", "Width" have relatively narrow distributions.
#    - Some variables such as "Compression Ratio", "engine-size", "price" have outliers indicated by individual data points outside the whiskers of the box plots.
#
# 2. **Chart Type Selection**:
#    - Box plots were chosen because they are effective for summarizing the distribution of continuous variables, including measures such as median, quartiles, and potential outliers.
#
# 3. **Pre-attentive Attributes Used**:
#    - **Color**: A consistent color (#FF5733) is used for all box plots to maintain visual similarity.
#    - **Position (Y-axis)**: The position of the box plots along the Y-axis represents the distribution of each continuous variable.
#
# 4. **Gestalt Principles Used**:
#    - **Proximity**: Box plots are organized in a grid, allowing viewers to easily compare the distributions of different variables.
#    - **Similarity**: Consistent color and formatting are used for box plots, enhancing visual similarity and making it easier to identify commonalities and differences.
#
# In summary, the box plots provide a clear and concise summary of the distribution of continuous variables, allowing us to quickly assess the central tendency, spread, and potential outliers in each variable.

# %% [markdown]
#   ### Question 4
#   <h4> Perform a Descriptive Statistical Analysis of the data set.<br>
#     Compute basic statistics for all variables of type 'Object'.
#     <h4>Answer in markdown cells below the visual <br><br>
#         1.Summarise your findings from the visual.<br>
#             2.The reason for selecting the chart type you did. <br>
#                 3.Mention the pre-attentive attributes used.(atleast 2)<br>
#                     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Identify object-type variables
object_vars = auto.select_dtypes(include=['object'])

# Display the object-type variables
print("Object-Type Variables:")
print(object_vars.columns)

### Frequency Distribution and Percentage Distribution:

for var in object_vars.columns:
    # Frequency distribution
    freq_dist = auto[var].value_counts()
    print(f"\nFrequency Distribution for {var}:")
    print("------------------------------------")
    print(freq_dist)

    # Percentage distribution
    percent_dist = auto[var].value_counts(normalize=True) * 100
    print(f"\nPercentage Distribution for {var}:")
    print("------------------------------------")
    print(percent_dist)

    ### Summary Statistics (Mode):
    mode = auto[var].mode().values[0]
    print(f"\nMode for {var}: {mode}")
    print("=====================================")
    print("=====================================")
# Out:
# Object-Type Variables:
# Index(['make', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels',
#        'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system',
#        'horsepower-binned'],
#       dtype='object')
#
# Frequency Distribution for make:
# ------------------------------------
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64
#
# Percentage Distribution for make:
# ------------------------------------
# toyota           15.920398
# nissan            8.955224
# mazda             8.457711
# ...

# %%
# Get object-type columns from the dataset
object_vars = auto.select_dtypes(include=['object']).columns

# Set a custom color palette for the count plots
#custom_palette = ['#FF5733', '#33FF57', '#5733FF', '#FF3399', '#33CCFF']
custom_palette = ['#e0e1f3']


# Create separate count plots for each object variable
for var in object_vars:
    if len(auto[str(var)].unique()) > 10:
      plt.figure(figsize=(20, 4))
    elif len(auto[str(var)].unique()) < 5:
      plt.figure(figsize=(4, 4))
    else:
      plt.figure(figsize=(8, 4))
    plt.title(f'Distribution of {var.replace("-", " ").title()}', fontsize=16, fontweight='bold')

    counts = auto[var].value_counts()
    ax = sns.countplot(data=auto, x=var, palette=custom_palette)
    tick_positions = [i for i in range(0, len(auto[str(var)].unique()))]
    tick_labels = auto[str(var)].unique().tolist()
    ax.set_xticks(tick_positions)
    ax.set_xticklabels(tick_labels)

    plt.xlabel(f'{var.replace("-", " ").title()}', fontsize=12)
    plt.ylabel('Count', fontsize=12)

    plt.xticks(rotation=0)

    plt.tight_layout()
    plt.show(ax)

# %% [markdown]
# **Findings**:
#
# 1. **Summarized Findings**:
#    - The count plots provide a summary of the distribution of each object-type variable in the dataset.
#    - Each count plot displays the count of occurrences of each category within the respective variable.
#    - It's easy to identify the most frequent categories within each variable.
#    - Based on the frequency/percentage distribution and mode analysis we can deduce the following
# *   make: Toyota has highest share with ~16% followed by Nissan, Mazda at 8-9%
# *   aspiration: 82% contains std
# *   num-of-doors: 57% being four and rest are two
# *   body-style: ~47% is sedan, followed by ~34% hatch back
# *   drive-wheels: ~59% is fwd and rest are rwd and 4wd
# *   engine-location: ~98% are front
# *   engine-type: 72% are ohc based
# *   num-of-cylinders: 78% are four cylinders and rest are six and five
# *   fuel-system: 45.8% being mpfi, 32% 2bbl, 10% with idi
# *   horsepower-binned: many are with Low (57.5 %), and rest are medium and high
#
# 2. **Chart Type Selection**:
#    - Count plots were chosen because they are effective for summarizing the distribution of categorical variables.
#
# 3. **Pre-attentive Attributes Used**:
#    - **Color**: Single color palette with is used to minizie the color noise and easily read the variations
#    - **Position (X and Y)**: The position of data bars along the x-axis represents the categories, while the height of the bars represents the count.
#
# 4. **Gestalt Principles Used**:
#    - **Proximity**: Count plots are organized in a row, allowing viewers to easily compare the distribution of different object-type variables.
#    - **Similarity**: Consistent color and formatting are used for count plots, enhancing visual similarity and making it easier to identify commonalities and differences.
#    - **Continuity**: The continuous representation of data bars within each count plot allows viewers to assess the distribution of categories.
#    - **Closure**: The subplots provide closure around each individual analysis, separating and organizing the visualizations.
#
# In summary, the count plots effectively summarize the distribution of object-type variables in the dataset, allowing us to quickly assess the frequency of different categories within each variable.
#
# ===============================================================================

# %% [markdown]
# ### Question 5
# <h4> Use a single heat map to visualize the relationship between Body Style and Drive-wheel vs Price.</h4>
# <h4>Perform the data preprocessing required.<br>
#
# <p>The heatmap should plot  the target variable (price) proportional to colour with respect to the variables 'drive-wheel' and 'body-style' in the vertical and horizontal axis respectively. This allows us to visualize how the price is related to 'drive-wheel' and 'body-style'.</p>
#
# The plot should have labels for x axis and y axis<br>
# Write down your observations in a markdown cell below the visual</h4>
#
# 1.Mention the pre-attentive attributes used.(atleast 2)<br>
# 2.Mention the gestalt principles used.(atleast 2)<br>

# %%
# Pivot the data to create the required format for the heatmap
heatmap_data = auto.pivot_table(index='body-style', columns='drive-wheels', values='price')

# Normalize the price values for better visualization
heatmap_data = (heatmap_data - heatmap_data.min().min()) / (heatmap_data.max().max() - heatmap_data.min().min())

# Reorder rows and columns for better readability
heatmap_data = heatmap_data.reindex(index=['sedan', 'hatchback', 'wagon', 'hardtop', 'convertible'],
                                    columns=['fwd', 'rwd', '4wd'])

# Create the heatmap
plt.figure(figsize=(9, 6))
sns.heatmap(heatmap_data, cmap='Blues', annot=True, fmt=".5f", cbar=True)
plt.title('Heatmap: Relationship between Body Style and Drive-wheel vs. Price')
plt.xlabel('Drive-wheel')
plt.ylabel('Body Style')

plt.show()

# %% [markdown]
# From the heatmap, we can draw several key inferences regarding the relationship between "Body Style" and "Drive-wheel" with respect to car prices:
#
# 1. **Price Differences by Body Style and Drive-wheel**: The intensity of the colors in the heatmap represents the normalized car prices. We can observe that "convertible" and "hardtop" body styles generally have higher prices compared to "sedan," "hatchback," and "wagon" body styles. Additionally, for most body styles, "rwd" (rear-wheel drive) vehicles tend to have higher prices than "fwd" (front-wheel drive) and "4wd" (four-wheel drive) vehicles.
#
# 2. **Convertible and Hardtop Premium**: Among all body styles, "convertible" and "hardtop" vehicles with "rwd" have the highest prices, indicated by the darkest blue shades. This suggests that these body styles, especially when combined with rear-wheel drive, command a premium price.
#
# 3. **Sedans and Hatchbacks**: "Sedans" and "hatchbacks" with "fwd" are generally more affordable, shown by the lighter blue shades. This may indicate that these configurations are more budget-friendly options.
#
# 4. **Variation Within Body Styles**: Within a particular body style category, there can still be price variations based on the drive-wheel configuration. For example, "rwd" sedans generally have higher prices than "fwd" sedans.
#
# 5. **4wd Observations**: There is limited data for "4wd" configurations, but they tend to be in the mid-price range among body styles.
#
# 6. **Normalized Prices**: Keep in mind that the prices are normalized, so the specific price values are not represented here. Instead, we are focusing on relative price differences.
#
# Though this heatmap provides insights into the relationships between body style, drive-wheel, and price, it doesn't capture all factors that influence car prices. Other factors such as engine size, brand, and additional features can also play a significant role in determining the price of a car.
#
#
# **Pre-attentive Attributes:**
# 1. **Color**: We used a single color gradient (from light to dark blue) to represent the price values, making it easy to distinguish higher and lower prices.
# 2. **Position**: The position of each cell within the heatmap grid represents the combination of "Body Style" and "Drive-wheel," allowing us to compare different categories.
# 3. **Size**: The size of each cell (square) is standardized, ensuring that the focus remains on the color gradient and not on variations in cell size.
# 4. **Annotation**: Numerical values (price) are annotated within each cell, providing exact values for reference.
#
# **Gestalt Principles:**
# 1. **Proximity**: Cells with similar values (related body styles and drive wheels) are grouped together, aiding in the comparison of prices within those groups.
# 2. **Similarity**: The color gradient within each cell is similar to other cells, allowing us to quickly identify patterns and variations in prices.
# 3. **Closure**: The heatmap's grid structure forms a sense of closure, helping us perceive individual cells as data points within the whole.
# 4. **Continuity**: The smooth color gradient within each cell and across the heatmap grid provides continuity in visualizing price trends, making it easier to identify price patterns.

# %% [markdown]
# # Group's choice-2 Marks
#
# #### Frame 1 (more) question which will help in the EDA(Exploratory Data Analysis) of the given data set and answer the same using the best visual.
#
#  1. Write the question in a markdown cell
#  2. Below the question,in a coding cell,write the python code to create the visual to answer the question
#
# <h4> Answer in markdown cells below the visual <br><br>
#    1.Summarise your findings from the visual.<br>
#    2.The reason for selecting the chart type you did. <br>
#    3.Mention the pre-attentive attributes used.(atleast 2)<br>
#    4.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ### Question 6:
#
#
# *   What is the distribution of car prices (variable: "price") in the dataset ?
# *   How does it vary across different car makes (variable: "make")
# *   Can we identify any patterns or trends in the price distribution by car make?

# %%
# Create a violin plot to visualize the price distribution by car make
plt.figure(figsize=(30, 8))
ax = sns.violinplot(x="make", y="price", data=auto, palette="Set2")
ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
plt.xticks(rotation=0)
plt.xlabel("Car Make", fontsize = 18)
plt.ylabel("Price", fontsize = 18)
plt.title("Price Distribution by Car Make", fontsize = 24)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **Summary of Findings:**
# - The violin plot provides a visual representation of the price distribution for each car make.
# - Some car makes, such as "jaguar," "mercedes-benz," and "porsche," tend to have a wide range of prices, with some high-priced outliers.
# - Other car makes, such as "chevrolet," "dodge," and "plymouth," generally have lower-priced vehicles.
# - There are variations in price distribution patterns among different car makes, with some makes having a more concentrated price range (mercedes-benz, porsche, bmw), while others have a broader range(chevrolet, renault) and no much distribution for mercury (only one data point available)
#
# **Reason for Chart Selection:**
# A violin plot is chosen because it effectively displays the distribution of prices for each car make, showing not only the central tendency but also the spread and any potential multimodal patterns.
#
# **Pre-attentive Attributes Used:**
# - Position (vertical position of violin plots for price distribution)
# - Length (width of the violin plots indicates density)
#
# **Gestalt Principles Used:**
# - Proximity (violin plots for the same car make are grouped together)
# - Similarity (violins share a common visual encoding for price distribution)

# %% [markdown]
# <h3><center>END OF ASSIGNMENT</center><h34>
